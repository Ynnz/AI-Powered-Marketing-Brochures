# %%
import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that have been scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page": "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page": "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/posts',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/Qwen/Qwen2.5-Omni-7B',
#  '/deepseek-ai/DeepSeek-V3-0324',
#  '/all-hands/openhands-lm-32b-v0.1',
#  '/openfree/flux-chatgpt-ghibli-lora',
#  '/ByteDance/MegaTTS3',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/jamesliu1217/EasyControl_Ghibli',
#  '/spaces/VAST-AI/TripoSG',
#  '/spaces/ByteDance/InfiniteYou-FLUX',
#  '/spaces/Stable-X/Hi3DGen',
#  '/spaces',
#  '/datasets/nvidia/Llama-Nemotron-Post-Training-Dataset-v1',
#  '/datasets/virtuoussy/Multi-subject-RLVR',
#  '/datasets/FreedomIntelligence/medical-o1-reasoning-SFT',
#  '/datasets/glaiveai/reasoning-v1-20m',
#  '/datasets/open-thoughts/OpenThoughts2-1M',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/tasks',
#  'https://ui.endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/Qwen2.5-Omni-7B
# Updated
# 5 days ago
# •
# 83.9k
# •
# 1.18k
# deepseek-ai/DeepSeek-V3-0324
# Updated
# 10 days ago
# •
# 155k
# •
# 2.33k
# all-hands/openhands-lm-32b-v0.1
# Updated
# 2 days ago
# •
# 3.2k
# •
# 251
# openfree/flux-chatgpt-ghibli-lora
# Updated
# about 11 hours ago
# •
# 5.78k
# •
# 263
# ByteDance/MegaTTS3
# Updated
# 1 day ago
# •
# 566
# •
# 242
# Browse 1M+ models
# Spaces
# Running
# 2.62k
# 2.62k
# DeepSite
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 551
# 551
# EasyControl Ghibli
# 🦀
# New Ghibli EasyControl model is now released!!
# Running
# on
# Zero
# 354
# 354
# TripoSG
# 🔮
# Generate 3D models from images
# Running
# on
# Zero
# 785
# 785
# InfiniteYou-FLUX
# 📸
# Flexible Photo Recrafting While Preserving Your Identity
# Running
# on
# Zero
# 289
# 289
# Hi3DGen
# 🏢
# High-fidelity 3D Geometry Generation from images
# Browse 400k+ applications
# Datasets
# nvidia/Llama-Nemotron-Post-Training-Dataset-v1
# Updated
# 18 days ago
# •
# 12.3k
# •
# 318
# virtuoussy/Multi-subject-RLVR
# Updated
# 3 days ago
# •
# 438
# •
# 40
# FreedomIntelligence/medical-o1-reasoning-SFT
# Updated
# Feb 22
# •
# 23k
# •
# 610
# glaiveai/reasoning-v1-20m
# Updated
# 17 days ago
# •
# 9.69k
# •
# 167
# open-thoughts/OpenThoughts2-1M
# Updated
# 2 days ago
# •
# 1.22k
# •
# 35
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 396 models
# •
# 3.01k followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.38k followers
# Amazon
# company
# •
# 10 models
# •
# 2.95k followers
# Google
# company
# •
# 982 models
# •
# 11.1k followers
# Intel
# company
# •
# 219 models
# •
# 2.4k followers
# Microsoft
# company
# •
# 365 models
# •
# 10.9k followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 148 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 254 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 142,456
# State-of-the-art ML for PyTorch, TensorFlow, JAX
# Diffusers
# 28,421
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,204
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,493
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 9,560
# Fast tokenizers optimized for research & production
# TRL
# 13,034
# Train transformers LMs with reinforcement learning
# Transformers.js
# 13,361
# State-of-the-art ML running directly in your browser
# smolagents
# 16,437
# Smol library to build great agents in Python
# PEFT
# 18,023
# Parameter-efficient finetuning for large language models
# Datasets
# 19,941
# Access & share datasets for any ML tasks
# Text Generation Inference
# 9,968
# Serve language models with TGI optimized toolkit
# Accelerate
# 8,581
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 29,829
# AI & ML interests
# The AI community building the future.
# Recent Activity
# clem
# new
# activity
# about 21 hours ago
# huggingface/InferenceSupport:
# Shakker-Labs/AWPortraitCN2
# stevhliu
# new
# activity
# about 21 hours ago
# huggingface/documentation-images:
# Upload Image for Attention Mask Visualizer (Gemma2)
# stevhliu
# updated
# a dataset
# about 21 hours ago
# huggingface/documentation-images
# View all activity
# Articles
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 38
# Team members
# 211
# +177
# +164
# +143
# +133
# +113
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 483k
# •
# •
# 40
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 11.2M
# •
# •
# 656
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# Updated
# May 6, 2024
# •
# 2.29M
# •
# •
# 184
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# Updated
# Dec 19, 2023
# •
# 7.01M
# •
# •
# 727
# spaces
# 26
# Sort:
# 		Recently updated
# pinned
# Running
# 83
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 138
# Inference Playground
# 🔋
# Set and update website theme based on user preference
# huggingface
# 3 days ago
# Running
# 1
# Space Build
# 🐨
# Generate static files for spaces
# huggingface
# 8 days ago
# Running
# 23
# InferenceSupport
# 💥
# Discussions about the Inference Providers feature on the Hub
# huggingface
# 9 days ago
# Running
# 357
# AI Deadlines
# ⚡
# Schedule tasks efficiently using AI-generated deadlines
# huggingface
# 21 days ago
# Running
# 533
# Open Source Ai Year In Review 2024
# 😻
# What happened in open-source AI this year, and what’s next?
# huggingface
# Jan 8
# Expand 26
# 							spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/timesfm-tourism-monthly
# Updated
# 5 days ago
# •
# 55
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 6.58k
# •
# •
# 59
# huggingface/falcon-40b-gptq
# Text Generation
# •
# Updated
# Jun 14, 2023
# •
# 12
# •
# 12
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 48.1k
# •
# 9
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# Updated
# Mar 22, 2023
# •
# 178
# •
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 48.4k
# •
# 6
# huggingface/time-series-transformer-tourism-monthly
# Updated
# Feb 23, 2023
# •
# 36.9k
# •
# 20
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 21
# •
# 4
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 37.7k
# •
# 80
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 1
# Expand 16
# 							models
# datasets
# 42
# Sort:
# 		Recently updated
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 21 hours ago
# •
# 52
# •
# 3.63M
# •
# 58
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# 5 days ago
# •
# 1.6k
# •
# 899
# •
# 20
# huggingface/policy-docs
# Updated
# 16 days ago
# •
# 2.46k
# •
# 10
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# 21 days ago
# •
# 69
# •
# 522
# •
# 6
# huggingface/gemini-results-2025-03-03
# Viewer
# •
# Updated
# Mar 4
# •
# 17
# •
# 58
# huggingface/gemini-results-2025-02-28
# Viewer
# •
# Updated
# Mar 1
# •
# 21
# •
# 38
# huggingface/gemini-results-2025-02-27
# Viewer
# •
# Updated
# Feb 28
# •
# 24
# •
# 41
# huggingface/gemini-results-2025-02-25
# Viewer
# •
# Updated
# Feb 26
# •
# 32
# •
# 37
# huggingface/gemini-results-2025-02-24
# Viewer
# •
# Updated
# Feb 25
# •
# 32
# •
# 30
# huggingface/gemini-results-2025-02-21
# Viewer
# •
# Updated
# Feb 22
# •
# 29
# •
# 120
# •
# 1
# Expand 42
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# enterprise page
# Webpage Title:
# Enterprise Hub - Hugging Face
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Enterprise Hub
# Enterprise-ready version of the world’s leading AI platform
# Subscribe to
# Enterprise Hub
# for $20/user/month with your Hub organization
# Give your organization the most advanced platform to build AI with enterprise-grade security, access controls,
# 			dedicated support and more.
# Single Sign-On
# Connect securely to your identity provider with SSO integration.
# Regions
# Select, manage, and audit the location of your repository data.
# Audit Logs
# Stay in control with comprehensive logs that report on actions taken.
# Resource Groups
# Accurately manage access to repositories with granular access control.
# Token Management
# Centralized token control and custom approval policies for organization access.
# Analytics
# Track and analyze repository usage data in a single dashboard.
# Advanced Compute Options
# Increase scalability and performance with more compute options like ZeroGPU.
# ZeroGPU Quota Boost
# All organization members get 5x more ZeroGPU quota to get the most of Spaces.
# Private Datasets Viewer
# Enable the Dataset Viewer on your private datasets for easier collaboration.
# Advanced security
# Configure organization-wide security policies and default repository visibility.
# Billing
# Control your budget effectively with managed billing and yearly commit options.
# Priority Support
# Maximize your platform usage with priority support from the Hugging Face team.
# Extra Private Storage
# Get an additional 1 TB of private storage for each member of your organization (then $25/month per extra TB).
# Join the most forward-thinking AI organizations
# Everything you already know and love about Hugging Face in Enterprise mode.
# Subscribe to
# Enterprise Hub
# or
# Talk to sales
# NVIDIA
# Enterprise
# company
# •
# 333 models
# •
# 21.1k followers
# Nerdy Face
# Enterprise
# company
# •
# 1 model
# •
# 287 followers
# AMD
# Enterprise
# company
# •
# 113 models
# •
# 1.44k followers
# Together
# Enterprise
# company
# •
# 32 models
# •
# 552 followers
# Xsolla
# Enterprise
# company
# •
# 125 followers
# Fidelity Investments
# Enterprise
# company
# •
# 133 followers
# Mercedes-Benz AG
# Enterprise
# company
# •
# 146 followers
# VIDraft
# Enterprise
# company
# •
# 6 models
# •
# 130 followers
# Technology Innovation Institute
# Enterprise
# company
# •
# 65 models
# •
# 1.28k followers
# creditkarma
# Enterprise
# company
# •
# 56 followers
# HiddenLayer
# Enterprise
# company
# •
# 1 model
# •
# 67 followers
# MiniMax
# Enterprise
# company
# •
# 2 models
# •
# 601 followers
# Stability AI
# Enterprise
# company
# •
# 104 models
# •
# 20.3k followers
# Adyen
# Enterprise
# company
# •
# 59 followers
# Meta Llama
# Enterprise
# company
# •
# 57 models
# •
# 35.4k followers
# Snowflake
# Enterprise
# company
# •
# 17 models
# •
# 479 followers
# Orange
# Enterprise
# company
# •
# 7 models
# •
# 204 followers
# Arm
# Enterprise
# company
# •
# 163 followers
# ServiceNow-AI
# Enterprise
# company
# •
# 199 followers
# Toyota Research Institute
# Enterprise
# company
# •
# 10 models
# •
# 105 followers
# Mistral AI_
# Enterprise
# company
# •
# 26 models
# •
# 7.35k followers
# H2O.ai
# Enterprise
# company
# •
# 72 models
# •
# 411 followers
# Aledade Inc
# Enterprise
# company
# •
# 64 followers
# ginigen
# Enterprise
# company
# •
# 1 model
# •
# 115 followers
# Grammarly
# Enterprise
# company
# •
# 10 models
# •
# 148 followers
# Widn AI
# Enterprise
# company
# •
# 43 followers
# BCG X
# Enterprise
# company
# •
# 37 followers
# Kakao Corp.
# Enterprise
# company
# •
# 3 models
# •
# 111 followers
# Shopify
# Enterprise
# company
# •
# 435 followers
# AI at Meta
# Enterprise
# company
# •
# 2.07k models
# •
# 5.38k followers
# Qwen
# Enterprise
# company
# •
# 235 models
# •
# 24.2k followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 254 followers
# Deutsche Telekom AG
# Enterprise
# company
# •
# 7 models
# •
# 137 followers
# Jusbrasil
# Enterprise
# company
# •
# 89 followers
# TNG Technology Consulting GmbH
# Enterprise
# company
# •
# 1 model
# •
# 68 followers
# IBM Granite
# Enterprise
# company
# •
# 96 models
# •
# 1.37k followers
# Chegg Inc
# Enterprise
# company
# •
# 84 followers
# Nutanix
# Enterprise
# company
# •
# 262 models
# •
# 66 followers
# Johnson & Johnson
# Enterprise
# company
# •
# 58 followers
# Liquid AI
# Enterprise
# company
# •
# 119 followers
# Novo Nordisk
# Enterprise
# company
# •
# 70 followers
# Ekimetrics
# Enterprise
# company
# •
# 56 followers
# Compliance & Certifications
# GDPR Compliant
# SOC 2 Type 2
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# pricing page
# Webpage Title:
# Hugging Face – Pricing
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Pricing
# Leveling up AI collaboration and compute.
# Users and organizations already use the Hub as a collaboration platform,
# we’re making it easy to seamlessly and scalably launch ML compute directly from the Hub.
# HF Hub
# Collaborate on Machine Learning
# Host unlimited public models, datasets
# Create unlimited orgs with no member limits
# Access the latest ML tools and open source
# Community support
# Forever
# Free
# PRO
# Pro Account
# Unlock advanced HF features
# ZeroGPU and Dev Mode for Spaces
# Free credits across all Inference Providers
# Get early access to upcoming features
# Show your support with a Pro badge
# Subscribe for
# $9
# /month
# Enterprise Hub
# Accelerate your AI roadmap
# SSO and SAML support
# Select data location with Storage Regions
# Precise actions reviews with Audit logs
# Granular access control with Resource groups
# Centralized token control and approval
# Dataset Viewer for private datasets
# Advanced compute options for Spaces
# 5x more ZeroGPU quota for all org members
# Deploy Inference on your own Infra
# Managed billing with yearly commits
# Priority support
# Starting at
# $20
# per user per month
# Spaces Hardware
# Upgrade your Space compute
# Free CPUs
# Build more advanced Spaces
# 7 optimized hardware available
# From CPU to GPU to Accelerators
# Starting at
# $0
# /hour
# Inference Endpoints
# Deploy models on fully managed infrastructure
# Deploy dedicated Endpoints in seconds
# Keep your costs low
# Fully-managed autoscaling
# Enterprise security
# Starting at
# $0.032
# /hour
# Need support to accelerate AI in your organization? View our
# Expert Support
# .
# Hugging Face Hub
# free
# The HF Hub is the central place to explore, experiment, collaborate and build technology with Machine
# 					Learning.
# Join the open source Machine Learning movement!
# →
# Sign Up
# Create with ML
# Packed with ML features, like model eval, dataset viewer and much more.
# Collaborate
# Git based and designed for collaboration at its core.
# Play and learn
# Learn by experimenting and sharing with our awesome community.
# Build your ML portfolio
# Share your work with the world and build your own ML profile.
# Spaces Hardware
# Starting at $0
# Spaces are one of the most popular ways to share ML applications and demos with the world.
# Upgrade your Spaces with our selection of custom on-demand hardware:
# →
# Get started with Spaces
# Name
# CPU
# Memory
# Accelerator
# VRAM
# Hourly price
# CPU Basic
# 2 vCPU
# 16 GB
# -
# -
# FREE
# CPU Upgrade
# 8 vCPU
# 32 GB
# -
# -
# $0.03
# Nvidia T4 - small
# 4 vCPU
# 15 GB
# Nvidia T4
# 16 GB
# $0.40
# Nvidia T4 - medium
# 8 vCPU
# 30 GB
# Nvidia T4
# 16 GB
# $0.60
# 1x Nvidia L4
# 8 vCPU
# 30 GB
# Nvidia L4
# 24 GB
# $0.80
# 4x Nvidia L4
# 48 vCPU
# 186 GB
# Nvidia L4
# 96 GB
# $3.80
# 1x Nvidia L40S
# 8 vCPU
# 62 GB
# Nvidia L4
# 48 GB
# $1.80
# 4x Nvidia L40S
# 48 vCPU
# 382 GB
# Nvidia L4
# 192 GB
# $8.30
# 8x Nvidia L40S
# 192 vCPU
# 1534 GB
# Nvidia L4
# 384 GB
# $23.50
# Nvidia A10G - small
# 4 vCPU
# 15 GB
# Nvidia A10G
# 24 GB
# $1.00
# Nvidia A10G - large
# 12 vCPU
# 46 GB
# Nvidia A10G
# 24 GB
# $1.50
# 2x Nvidia A10G - large
# 24 vCPU
# 92 GB
# Nvidia A10G
# 48 GB
# $3.00
# 4x Nvidia A10G - large
# 48 vCPU
# 184 GB
# Nvidia A10G
# 96 GB
# $5.00
# Nvidia A100 - large
# 12 vCPU
# 142 GB
# Nvidia A100
# 80 GB
# $4.00
# Custom
# on demand
# on demand
# on demand
# on demand
# on demand
# Spaces Persistent Storage
# All Spaces get ephemeral storage for free but you can upgrade and add persistent storage at any time.
# Name
# Storage
# Monthly price
# Small
# 20 GB
# $5
# Medium
# 150 GB
# $25
# Large
# 1 TB
# $100
# Building something cool as a side project? We also offer community GPU grants.
# Inference Endpoints
# Starting at $0.033/hour
# Inference Endpoints (dedicated) offers a secure production solution to easily deploy any ML model on dedicated
# 					and autoscaling infrastructure, right from the HF Hub.
# →
# Learn more
# CPU
# instances
# Provider
# Architecture
# vCPUs
# Memory
# Hourly rate
# aws
# Intel Sapphire Rapids
# 1
# 2GB
# $0.03
# 2
# 4GB
# $0.07
# 4
# 8GB
# $0.13
# 8
# 16GB
# $0.27
# 16
# 32GB
# $0.54
# azure
# Intel Xeon
# 1
# 2GB
# $0.06
# 2
# 4GB
# $0.12
# 4
# 8GB
# $0.24
# 8
# 16GB
# $0.48
# gcp
# Intel Sapphire Rapids
# 1
# 2GB
# $0.05
# 2
# 4GB
# $0.10
# 4
# 8GB
# $0.20
# 8
# 16GB
# $0.40
# Accelerator
# instances
# Provider
# Architecture
# Topology
# Accelerator Memory
# Hourly rate
# aws
# Inf2
# 															Neuron
# x1
# 14.5GB
# $0.75
# x12
# 760GB
# $12.00
# gcp
# TPU
# 															v5e
# 1x1
# 16GB
# $1.20
# 2x2
# 64GB
# $4.75
# 2x4
# 128GB
# $9.50
# GPU
# instances
# Provider
# Architecture
# GPUs
# GPU Memory
# Hourly rate
# aws
# NVIDIA T4
# 1
# 14GB
# $0.50
# 4
# 56GB
# $3.00
# aws
# NVIDIA L4
# 1
# 24GB
# $0.80
# 4
# 96GB
# $3.80
# aws
# NVIDIA L40S
# 1
# 48GB
# $1.80
# 4
# 192GB
# $8.30
# 8
# 384GB
# $23.50
# aws
# NVIDIA A10G
# 1
# 24GB
# $1.00
# 4
# 96GB
# $5.00
# aws
# NVIDIA A100
# 1
# 80GB
# $4.00
# 2
# 160GB
# $8.00
# 4
# 320GB
# $16.00
# 8
# 640GB
# $32.00
# gcp
# NVIDIA T4
# 1
# 16GB
# $0.50
# gcp
# NVIDIA L4
# 1
# 24GB
# $0.70
# 4
# 96GB
# $3.80
# gcp
# NVIDIA A100
# 1
# 80GB
# $3.60
# 2
# 160GB
# $7.20
# 4
# 320GB
# $14.40
# 8
# 640GB
# $28.80
# gcp
# NVIDIA H100
# 1
# 80GB
# $10.00
# 2
# 160GB
# $20.00
# 4
# 320GB
# $40.00
# 8
# 640GB
# $80.00
# Pro Account
# PRO
# A monthly subscription to access powerful features.
# →
# Get Pro
# ($9/month)
# ZeroGPU
# : Get 5x usage quota and highest GPU queue priority
# Spaces Hosting
# : Create ZeroGPU Spaces with A100 hardware
# Spaces Dev Mode
# : Fast iterations via SSH/VS Code for Spaces
# Inference Providers
# : Get $2 included credits across all Inference Providers
# Dataset Viewer
# : Activate it on private datasets
# Blog Articles
# : Publish articles to the Hugging Face blog
# Social Posts
# : Share short updates with the community
# Features Preview
# : Get early access to upcoming
# 										features
# PRO
# Badge
# :
# 										Show your support on your profile
# System theme
# Website
# Models
# Datasets
# Spaces
# Tasks
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Posts
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Journey to 1 Million Gradio Users!
# By
# abidlabs
# April 4, 2025
# •
# 1
# Community Articles
# view all
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# 19 days ago
# •
# 125
# Custom Vibe Coding Quest Part 2: 🚙 Fine-Tuning Gemma 3 for Code Reasoning
# By
# burtenshaw
# •
# 4 days ago
# •
# 17
# Querying Hugging Face Datasets with the DuckDB UI
# By
# cfahlgren1
# •
# 3 days ago
# •
# 14
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 508
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 157
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# 22 days ago
# •
# 98
# Ghibli AI: The Ultimate Guide to Studio Ghibli-Style AI Image Generation
# By
# LLMhacker
# •
# 6 days ago
# •
# 9
# Everyone Can Optimise AI Models and Make Them Faster, Smaller, Cheaper, Greener
# By
# PrunaAI
# and 2 others
# •
# 1 day ago
# •
# 9
# Training YOLOv8 with Synthetic Data from Falcon
# By
# DualityAI-RebekahBogdanoff
# •
# 4 days ago
# •
# 8
# Training Large Language Models with Interpreter Feedback using WebAssembly
# By
# axolotl-ai-co
# and 1 other
# •
# 2 days ago
# •
# 8
# Porting Pi0-FAST to LeRobot from JAX to PyTorch: Challenges, Fixes, and Open Questions
# By
# danaaubakirova
# and 3 others
# •
# 3 days ago
# •
# 7
# Efficient Request Queueing – Optimizing LLM Performance
# By
# tngtech
# •
# 3 days ago
# •
# 7
# Custom Vibe Coding Quest Part 1: The Quest Begins 🧙
# By
# burtenshaw
# •
# 10 days ago
# •
# 7
# Microsoft Playwright MCP: Tutorial for Beginners
# By
# lynn-mikami
# •
# 8 days ago
# •
# 8
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 232
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 94
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# about 1 month ago
# •
# 156
# Digest of models based on YandexGPT 5 Lite
# By
# WaveCut
# •
# 17 days ago
# •
# 30
# I Clicked “I Agree”, But What Am I Really Consenting To?
# By
# giadap
# •
# 10 days ago
# •
# 24
# Efficient Deep Learning: A Comprehensive Overview of Optimization Techniques 👐 📚
# By
# Isayoften
# •
# Aug 26, 2024
# •
# 56
# The NLP Course is becoming the LLM Course!
# By
# burtenshaw
# April 3, 2025
# •
# 47
# How Hugging Face Scaled Secrets Management for AI Infrastructure
# By
# segudev
# March 31, 2025
# guest
# •
# 4
# Accelerating LLM Inference with TGI on Intel Gaudi
# By
# baptistecolle
# March 28, 2025
# •
# 12
# Training and Finetuning Reranker Models with Sentence Transformers v4
# By
# tomaarsen
# March 26, 2025
# •
# 96
# Introducing Gradio's new Dataframe!
# By
# hmb
# March 24, 2025
# •
# 22
# The New and Fresh analytics in Inference Endpoints
# By
# erikkaum
# March 21, 2025
# •
# 19
# Open R1: How to use OlympicCoder locally for coding?
# By
# burtenshaw
# March 20, 2025
# •
# 56
# AI Policy: 🤗 Response to the White House AI Action Plan RFI
# By
# yjernite
# March 19, 2025
# •
# 22
# NVIDIA's GTC 2025 Announcement for Physical AI Developers: New Open Models and Datasets
# By
# mingyuliutw
# March 18, 2025
# guest
# •
# 33
# Xet is on the Hub
# By
# jsulz
# March 18, 2025
# •
# 41
# Welcome Gemma 3: Google's all new multimodal, multilingual, long context open LLM
# By
# ariG23498
# March 12, 2025
# •
# 371
# LeRobot goes to driving school: World’s largest open-source self-driving dataset
# By
# sandhawalia
# March 11, 2025
# •
# 73
# LLM Inference on Edge: A Fun and Easy Guide to run LLMs via React Native on your Phone!
# By
# medmekk
# March 7, 2025
# •
# 49
# Hugging Face and JFrog partner to make AI Security more transparent
# By
# mcpotato
# March 4, 2025
# •
# 21
# Previous
# 1
# 2
# 3
# ...
# 40
# Next
# Community Articles
# Sort:
# 		Trending
# 🦸🏻#14: What Is MCP, and Why Is Everyone – Suddenly!– Talking About It?
# By
# Kseniase
# •
# 19 days ago
# •
# 125
# Custom Vibe Coding Quest Part 2: 🚙 Fine-Tuning Gemma 3 for Code Reasoning
# By
# burtenshaw
# •
# 4 days ago
# •
# 17
# Querying Hugging Face Datasets with the DuckDB UI
# By
# cfahlgren1
# •
# 3 days ago
# •
# 14
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 508
# The Large Language Model Course
# By
# mlabonne
# •
# Jan 16
# •
# 157
# Open-Source Handwritten Signature Detection Model
# By
# samuellimabraz
# •
# 22 days ago
# •
# 98
# Ghibli AI: The Ultimate Guide to Studio Ghibli-Style AI Image Generation
# By
# LLMhacker
# •
# 6 days ago
# •
# 9
# Everyone Can Optimise AI Models and Make Them Faster, Smaller, Cheaper, Greener
# By
# PrunaAI
# and 2 others
# •
# 1 day ago
# •
# 9
# Training YOLOv8 with Synthetic Data from Falcon
# By
# DualityAI-RebekahBogdanoff
# •
# 4 days ago
# •
# 8
# Training Large Language Models with Interpreter Feedback using WebAssembly
# By
# axolotl-ai-co
# and 1 other
# •
# 2 days ago
# •
# 8
# Porting Pi0-FAST to LeRobot from JAX to PyTorch: Challenges, Fixes, and Open Questions
# By
# danaaubakirova
# and 3 others
# •
# 3 days ago
# •
# 7
# Efficient Request Queueing – Optimizing LLM Performance
# By
# tngtech
# •
# 3 days ago
# •
# 7
# Custom Vibe Coding Quest Part 1: The Quest Begins 🧙
# By
# burtenshaw
# •
# 10 days ago
# •
# 7
# Microsoft Playwright MCP: Tutorial for Beginners
# By
# lynn-mikami
# •
# 8 days ago
# •
# 8
# ColPali: Efficient Document Retrieval with Vision Language Models 👀
# By
# manu
# •
# Jul 5, 2024
# •
# 232
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 94
# Manus AI: The Best Autonomous AI Agent Redefining Automation and Productivity
# By
# LLMhacker
# •
# about 1 month ago
# •
# 156
# Digest of models based on YandexGPT 5 Lite
# By
# WaveCut
# •
# 17 days ago
# •
# 30
# I Clicked “I Agree”, But What Am I Really Consenting To?
# By
# giadap
# •
# 10 days ago
# •
# 24
# Efficient Deep Learning: A Comprehensive Overview of Optimization Techniques 👐 📚
# By
# Isayoften
# •
# Aug 26, 2024
# •
# 56
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# community forum
# Webpage Title:
# Hugging Face Forums - Hugging Face Community Discussion
# Webpage Contents:
# Hugging Face Forums
# Topic
# Replies
# Views
# Activity
# Reduce the restart time
# Spaces
# 2
# 5
# April 5, 2025
# Need Help for News Summary fine tuning using flan t5
# Beginners
# 2
# 10
# April 5, 2025
# Sort models by cost (reccomendation)
# Beginners
# 0
# 6
# April 5, 2025
# Having trouble deploying a Hugging Face model on GCP Vertex AI
# Beginners
# 1
# 11
# April 5, 2025
# Tables & Numerical Data in PDFs to -> Excel
# Beginners
# 1
# 9
# April 5, 2025
# Attention mask shape (custom attention masking)
# 🤗Transformers
# 2
# 417
# April 5, 2025
# Why does my ChatGPT system prompt make it sentient?
# Models
# 1
# 12
# April 5, 2025
# Issue with Code?
# Beginners
# 3
# 12
# April 5, 2025
# Can I use one MCP host as a server for another MCP host in a hierarchical multi-agent architecture?
# Beginners
# 1
# 19
# April 4, 2025
# Dataset Tokenization to Fine-Tune Gemma 3 1B
# Beginners
# 2
# 15
# April 5, 2025
# UPDATE - @radames to this day STILL hasn't fixed Enhance This HiDiffusion SDXL, he DEFINITELY left off the face of the earth, can @John6666 or anybody try to fix this please?, thanks
# Spaces
# 6
# 17
# April 5, 2025
# Reward becomes nan when switching from full precision to fp16 for gemma3-12b-it
# 🤗Transformers
# 2
# 6
# April 5, 2025
# Smolagents Error: probability tensor contains either `inf`, `nan` or element < 0
# Beginners
# 5
# 18
# April 4, 2025
# Reducing unwanted generation in Gemma 3
# 🤗Transformers
# 7
# 16
# April 5, 2025
# Making a model "think" before doing a tool call (ReAct paper)
# Research
# 2
# 57
# April 4, 2025
# Shard Cannot Start/Inference endpoint error while deployment
# Models
# 4
# 132
# April 5, 2025
# Sales transcript training
# Beginners
# 2
# 17
# April 3, 2025
# Unable to Access Gated Model meta-llama/Llama-3.2-1B Despite Approved Access
# Models
# 5
# 21
# April 5, 2025
# BartForCausalLM vs BartForConditionalGeneration
# Beginners
# 0
# 8
# April 4, 2025
# Complex OCR scenarios
# Models
# 1
# 11
# April 4, 2025
# How to increase inference quota
# Models
# 3
# 16
# April 4, 2025
# Space will not build
# Beginners
# 3
# 7
# April 4, 2025
# 🧠 Symbolic Memory Tools for Local LLMs – Reflection Scaffolds & Recovery Protocols
# Show and Tell
# 0
# 7
# April 4, 2025
# Calculating VLM and VLA Loss
# Beginners
# 0
# 7
# April 4, 2025
# Vertex AI - The token is not valid or not have permission
# Beginners
# 12
# 1681
# April 5, 2025
# Paper authorship claim denied.And I have tried many times but failed
# Beginners
# 1
# 14
# April 4, 2025
# Is the rule of 25 min changed?
# 🤗Hub
# 7
# 110
# April 4, 2025
# Is there specific generative model to describe User Interfaces?
# Models
# 4
# 32
# April 2, 2025
# Transformers - repetition_penalty parameter
# Beginners
# 3
# 29222
# April 4, 2025
# I'm having an error message working with my User access tokens
# Inference Endpoints on the Hub
# 17
# 10978
# April 4, 2025
# next page →
# Home
# Categories
# Guidelines
# Terms of Service
# Privacy Policy
# Powered by
# Discourse
# , best viewed with JavaScript enabled
#
#
#
# GitHub page
# Webpage Title:
# Hugging Face · GitHub
# Webpage Contents:
# Skip to content
# Navigation Menu
# Toggle navigation
# Sign in
# huggingface
# Product
# GitHub Copilot
# Write better code with AI
# GitHub Advanced Security
# Find and fix vulnerabilities
# Actions
# Automate any workflow
# Codespaces
# Instant dev environments
# Issues
# Plan and track work
# Code Review
# Manage code changes
# Discussions
# Collaborate outside of code
# Code Search
# Find more, search less
# Explore
# All features
# Documentation
# GitHub Skills
# Blog
# Solutions
# By company size
# Enterprises
# Small and medium teams
# Startups
# Nonprofits
# By use case
# DevSecOps
# DevOps
# CI/CD
# View all use cases
# By industry
# Healthcare
# Financial services
# Manufacturing
# Government
# View all industries
# View all solutions
# Resources
# Topics
# AI
# DevOps
# Security
# Software Development
# View all
# Explore
# Learning Pathways
# Events & Webinars
# Ebooks & Whitepapers
# Customer Stories
# Partners
# Executive Insights
# Open Source
# GitHub Sponsors
# Fund open source developers
# The ReadME Project
# GitHub community articles
# Repositories
# Topics
# Trending
# Collections
# Enterprise
# Enterprise platform
# AI-powered developer platform
# Available add-ons
# GitHub Advanced Security
# Enterprise-grade security features
# Copilot for business
# Enterprise-grade AI features
# Premium Support
# Enterprise-grade 24/7 support
# Pricing
# Search or jump to...
# Search code, repositories, users, issues, pull requests...
# Search
# Clear
# Search syntax tips
# Provide feedback
# We read every piece of feedback, and take your input very seriously.
# Include my email address so I can be contacted
# Cancel
# Submit feedback
# Saved searches
# Use saved searches to filter your results more quickly
# Cancel
# Create saved search
# Sign in
# Sign up
# Reseting focus
# You signed in with another tab or window.
# Reload
# to refresh your session.
# You signed out in another tab or window.
# Reload
# to refresh your session.
# You switched accounts on another tab or window.
# Reload
# to refresh your session.
# Dismiss alert
# Hugging Face
# The AI community building the future.
# Verified
# We've verified that the organization
# huggingface
# controls the domain:
# huggingface.co
# Learn more about verified organizations
# 47.1k
# followers
# NYC + Paris
# https://huggingface.co/
# X
# @huggingface
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# 0
# More
# Overview
# Repositories
# Projects
# Packages
# People
# Sponsoring
# Pinned
# Loading
# transformers
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# Python
# 142k
# 28.5k
# diffusers
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# Python
# 28.4k
# 5.8k
# datasets
# datasets
# Public
# 🤗 The largest hub of ready-to-use datasets for ML models with fast, easy-to-use and efficient data manipulation tools
# Python
# 19.9k
# 2.8k
# peft
# peft
# Public
# 🤗 PEFT: State-of-the-art Parameter-Efficient Fine-Tuning.
# Python
# 18k
# 1.8k
# accelerate
# accelerate
# Public
# 🚀 A simple way to launch, train, and use PyTorch models on almost any device and distributed configuration, automatic mixed precision (including fp8), and easy-to-configure FSDP and DeepSpeed support
# Python
# 8.6k
# 1.1k
# optimum
# optimum
# Public
# 🚀 Accelerate inference and training of 🤗 Transformers, Diffusers, TIMM and Sentence Transformers with easy to use hardware optimization tools
# Python
# 2.8k
# 518
# Repositories
# Loading
# Type
# Select type
# Forks
# Archived
# Mirrors
# Templates
# Language
# Select language
# All
# C
# C#
# C++
# Cuda
# Dockerfile
# Go
# HTML
# Java
# JavaScript
# Jupyter Notebook
# Kotlin
# Lua
# MDX
# Mustache
# Nix
# Python
# Rust
# Shell
# Smarty
# Swift
# TypeScript
# Sort
# Select order
# Last updated
# Name
# Stars
# Showing 10 of 302 repositories
# transformers
# Public
# 🤗 Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# huggingface/transformers’s past year of commit activity
# Python
# 142,455
# Apache-2.0
# 28,540
# 1,050
# (2 issues need help)
# 677
# Updated
# Apr 5, 2025
# candle
# Public
# Minimalist ML framework for Rust
# huggingface/candle’s past year of commit activity
# Rust
# 16,958
# Apache-2.0
# 1,074
# 402
# (5 issues need help)
# 107
# Updated
# Apr 5, 2025
# nanotron
# Public
# Minimalistic large language model 3D-parallelism training
# huggingface/nanotron’s past year of commit activity
# Python
# 1,760
# Apache-2.0
# 170
# 60
# (20 issues need help)
# 47
# Updated
# Apr 5, 2025
# text-embeddings-inference
# Public
# A blazing fast inference solution for text embeddings models
# huggingface/text-embeddings-inference’s past year of commit activity
# Rust
# 3,386
# Apache-2.0
# 235
# 119
# 11
# Updated
# Apr 5, 2025
# datatrove
# Public
# Freeing data processing from scripting madness by providing a set of platform-agnostic customizable pipeline processing blocks.
# huggingface/datatrove’s past year of commit activity
# Python
# 2,340
# Apache-2.0
# 177
# 71
# 11
# Updated
# Apr 5, 2025
# diffusers
# Public
# 🤗 Diffusers: State-of-the-art diffusion models for image, video, and audio generation in PyTorch and FLAX.
# huggingface/diffusers’s past year of commit activity
# Python
# 28,421
# Apache-2.0
# 5,823
# 467
# (11 issues need help)
# 184
# Updated
# Apr 5, 2025
# trl
# Public
# Train transformer language models with reinforcement learning.
# huggingface/trl’s past year of commit activity
# Python
# 13,035
# Apache-2.0
# 1,769
# 341
# 83
# Updated
# Apr 5, 2025
# frp
# Public
# FRP Fork
# huggingface/frp’s past year of commit activity
# Go
# 160
# Apache-2.0
# 24
# 0
# 1
# Updated
# Apr 4, 2025
# smolagents
# Public
# 🤗 smolagents: a barebones library for agents that think in python code.
# huggingface/smolagents’s past year of commit activity
# Python
# 16,437
# Apache-2.0
# 1,445
# 113
# (1 issue needs help)
# 96
# Updated
# Apr 4, 2025
# hfendpoint-poc
# Public
# SDK for creating Hugging Face Inference Endpoints deployments
# huggingface/hfendpoint-poc’s past year of commit activity
# Python
# 1
# 1
# 0
# 0
# Updated
# Apr 4, 2025
# View all repositories
# People
# View all
# Top languages
# Python
# Jupyter Notebook
# Rust
# TypeScript
# JavaScript
# Most used topics
# pytorch
# machine-learning
# nlp
# transformers
# deep-learning
# Footer
# © 2025 GitHub, Inc.
# Footer navigation
# Terms
# Privacy
# Security
# Status
# Docs
# Contact
# Manage cookies
# Do not share my personal information
# You can’t perform that action at this time.
#
#
#
# Twitter page
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# LinkedIn page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# LinkedIn and 3rd parties use essential and non-essential cookies to provide, secure, analyze and improve our Services, and to show you relevant ads (including
# professional and job ads
# ) on and off LinkedIn. Learn more in our
# Cookie Policy
# .
# Select Accept to consent or Reject to decline non-essential cookies for this use. You can update your choices at any time in your
# settings
# .
# Accept
# Reject
# Skip to main content
# LinkedIn
# Articles
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 517 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Bassem ASSEH
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# See all employees
# Updates
# Hugging Face
# reposted this
# Ben Burtenshaw
# Machine Learning Advocacy @ 🤗 Hugging Face
# 2d
# Edited
# Report this post
# Welcome to the LLM Course!
#
# Education has always been at the heart of Hugging Face’s mission to democratize AI and we’re doubling down on that by giving
# hf.co/learn
# a big upgrade! The newly renamed LLM course is getting:
#
# - New chapters on the latest topics
# - Improved legacy material on fundamentals
# - Interactive and live sessions
# - Collaborations with the community
#
# Everything is in this blog post, or follow the org for updates:
# https://lnkd.in/epgEBujr
# 594
# 22 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Clem Delangue 🤗
# Clem Delangue 🤗 is an Influencer
# Co-founder & CEO at Hugging Face
# 4d
# Report this post
# Gradio just crossed 1,000,000 monthly developers in March!
#
# In my opinion, it's become one of the most important tools for democratization of AI that powered massively impactful apps like LMArena, Stable diffusion, Illusion Diffusion, InstantID, Kokoro, and thousands of new ones every day!
#
# Please join me in congratulating the
# Gradio
# team that joined
# Hugging Face
# almost 4 years ago, we're so happy to have them all!
#
# Now time for 10,000,000 users!
# 121
# 8 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,360 followers
# 3d
# Report this post
# 📊 1 MILLION DEVELOPERS ARE DEMOCRATIZING AI 📊
# Gradio has crossed 1M monthly active developers -- a milestone that represents more than just a number.
#
# 💯 It represents thousands of AI innovations being shared openly, tested quickly, and deployed globally.
#
# 🌉 From academic papers to production systems, Gradio has become the bridge connecting cutting-edge AI research with practical applications in:
# - Design
# - Finance
# - Education
# - Media
# - Learderboards
# - Enterprise solutions
#
# 🚩 This milestone validates our core belief: the most useful AI isn't the one with the most impressive benchmark numbers or best Ghibli converter, but the one that is the most accessible for builders and creators out there.
#
# 🤗 🧡 Thank you to the entire AI Community that made this possible. Here's to the next million!
# …more
# 107
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# 927,968 followers
# 3d
# Report this post
# 💣💥
#
# Inference Providers for organizations is UP
# Julien Chaumond
# CTO at Hugging Face
# 3d
# BOOOOM!
# We just launched Inference Providers for organizations 🔥
#
# (orgs need to be subscribed to
# Hugging Face
# Enterprise Hub given this feature requires billing)
#
# Some details ⤵️:
# - Each organization gets a pool of $2 of included usage per seat - shared among org members
# - Usage past those included credits is billed on top of the subscription (pay-as-you-go)
# - Organization admins can enable/disable usage of Inference Providers and set a spending limit (on top of included credits)
#
# Check the documentation on the Hub on how to bill your org for Inference Providers usage
#
# Feedback is welcome ❤️
# 36
# 3 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sergio Paniego Blanco
# ML Engineer @ Hugging Face 🤗 | AI PhD | Google Summer of Code '18-'24
# 4d
# Report this post
# 🆕New Unit in the Agents Course at
# Hugging Face
# .
#
# We just released the first Use Case on Agentic RAG—where we compare three frameworks side by side:
# 🤏 smolagents
# 🦙
# LlamaIndex
# 🦜 LangGraph (
# LangChain
# )
#
# 🔗 Course link:
# https://lnkd.in/dCnhGedq
# 705
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 5d
# Report this post
# What's the best open model for Chinese-to-English translation? I don't know! That's why I've just run a quick experiment 👇
#
#
# Today, I wanted to translate a very interesting Chinese dataset into English.
#
# Thanks to
# Hugging Face
# Inference Providers I compared V3, V3-0324, and Llama 70B using QwQ-32B as a translation quality evaluator.
#
# All without switching tools and providers and in under an hour!
#
# The result?
# V3 performs slightly better than V3-0324 (challenging my initial assumption), but both perform much better than Llama 70B.
#
# This is just a small dataset of 50 samples, but it gave me some instant insights about the task; I'll run some additional experiments on my final dataset.
#
# All prompts and the dataset are open source (see first comment)
# 38
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,360 followers
# 1w
# Edited
# Report this post
# Hi3DGen 🔥
#
# High-fidelity 3D geometry generation from a single image by leveraging normal maps as an intermediate representation
#
# Play with the fantastic app on
# Hugging Face
# now:
# https://lnkd.in/g99NpV_y
# …more
# 262
# 6 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Freddy Boulton
# Software Engineer @ 🤗
# 1w
# Report this post
# Generate lifelike audio in real-time without a GPU! 🚀
#
# Check out orpheus-cpp: a
# llama.cpp
# port of orpheus 3b text-to-speech model with built-in support for sync and async streaming.
#
# 𝚙𝚒𝚙 𝚒𝚗𝚜𝚝𝚊𝚕𝚕 𝚘𝚛𝚙𝚑𝚎𝚞𝚜-𝚌𝚙𝚙
# 𝚙𝚢𝚝𝚑𝚘𝚗 -𝚖 𝚘𝚛𝚙𝚑𝚎𝚞𝚜_𝚌𝚙𝚙
#
# Project code:
# https://lnkd.in/ekPpN9mc
# …more
# 462
# 13 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 61,360 followers
# 1w
# Report this post
# We just turned the humble dataframe into a superweapon⚡️
# dashboarding will never be the same!! 📊
#
# new Gradio Dataframe has:
# - multi-cell selection
# - column pinning
# - search + filtering
# - fullscreen mode
# - accessibility upgrades, and more
# …more
# 144
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗 | Google Developer Expert in Machine Learning, MSc Candidate in Data Science
# 1w
# Report this post
# is your vision LM in prod even safe? 👀
#
# ShieldGemma 2 is the first ever safety model for multimodal vision LMs in production by
# Google DeepMind
# , came with Gemma 3 🔥
#
# I saw confusion around how to use it, so I put together a notebook and a demo, find it in the comments 💬
# 427
# 11 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Mistral AI
# Technology, Information and Internet
# Paris, France
# Perplexity
# Software Development
# San Francisco, California
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Google DeepMind
# Research Services
# London, London
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Cohere
# Software Development
# Toronto, Ontario
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community page', 'url': 'https://discuss.huggingface.co'}, {'type': 'company LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'company GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'status page', 'url': 'https://status.huggingface.co/'}]}
# 'You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nPosts\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/Qwen2.5-Omni-7B\nUpdated\n5 days ago\n•\n83.9k\n•\n1.18k\ndeepseek-ai/DeepSeek-V3-0324\nUpdated\n10 days ago\n•\n155k\n•\n2.33k\nall-hands/openhands-lm-32b-v0.1\nUpdated\n2 days ago\n•\n3.2k\n•\n251\nopenfree/flux-chatgpt-ghibli-lora\nUpdated\nabout 11 hours ago\n•\n5.78k\n•\n263\nByteDance/MegaTTS3\nUpdated\n1 day ago\n•\n566\n•\n242\nBrowse 1M+ models\nSpaces\nRunning\n2.62k\n2.62k\nDeepSite\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n551\n551\nEasyControl Ghibli\n🦀\nNew Ghibli EasyControl model is now released!!\nRunning\non\nZero\n354\n354\nTripoSG\n🔮\nGenerate 3D models from images\nRunning\non\nZero\n785\n785\nInfiniteYou-FLUX\n📸\nFlexible Photo Recrafting While Preserving Your Identity\nRunning\non\nZero\n289\n289\nHi3DGen\n🏢\nHigh-fidelity 3D Geometry Generation from images\nBrowse 400k+ applications\nDatasets\nnvidia/Llama-Nemotron-Post-Training-Dataset-v1\nUpdated\n18 days ago\n•\n12.3k\n•\n319\nvirtuoussy/Multi-subject-RLVR\nUpdated\n3 days ago\n•\n438\n•\n40\nFreedomIntelligence/medical-o1-reasoning-SFT\nUpdated\nFeb 22\n•\n23k\n•\n610\nglaiveai/reasoning-v1-20m\nUpdated\n17 days ago\n•\n9.69k\n•\n167\nopen-thoughts/OpenThoughts2-1M\nUpdated\n2 days ago\n•\n1.22k\n•\n35\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nEnterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n396 models\n•\n3.01k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.07k models\n•\n5.38k followers\nAmazon\ncompany\n•\n10 models\n•\n2.95k followers\nGoogle\ncompany\n•\n982 models\n•\n11.1k followers\nIntel\ncompany\n•\n219 models\n•\n2.4k followers\nMicrosoft\ncompany\n•\n365 models\n•\n10.9k followers\nGrammarly\nEnterprise\ncompany\n•\n10 models\n•\n148 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n254 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n142,456\nState-of-the-art ML for PyTorch, TensorFlow, JAX\nDiffusers\n28,421\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,204\nSafe way to store/distribute neural network weights\nHub Python Library\n2,493\nPython client to interact with the Hugging Face Hub\nTokenizers\n9,560\nFast tokenizers optimized for research & production\nTRL\n13,034\nTrain transformers LMs with reinforcement learning\nTransformers.js\n13,361\nState-of-the-art ML running directly in your browser\nsmolagents\n16,437\nSmol library to build great agents in Python\nPEFT\n18,023\nParameter-efficient finetuning for large language model ...

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Brochure
#
# ## Welcome to Hugging Face!
#
# ### The AI Community Building the Future
# At Hugging Face, we are on a mission to create an exceptional platform for the machine learning community. Our open-source tools and extensive resources empower individuals and organizations alike to innovate and collaborate in the evolving AI landscape. We offer a comprehensive suite that includes models, datasets, and applications, paving the way for creativity and progress in artificial intelligence.
#
# ---
#
# ### Our Offerings
#
# #### Models
# - **Explore 1M+ models** in a variety of domains, including text, image, video, audio, and even 3D.
# - **Trending Models**: Check out the latest and most popular models like Qwen/Qwen2.5-Omni-7B, deepseek-ai/DeepSeek-V3-0324, and more!
#
# #### Datasets
# - Access over **250k datasets** catering to various machine learning tasks to help enhance your projects.
#
# #### Spaces
# - Collaborate on and host unlimited public models, datasets, and applications through our user-friendly Spaces platform.
#
# #### Enterprise Solutions
# - **Tailored for organizations**: Our enterprise features include enhanced security, access controls, and dedicated support, ensuring that teams can leverage AI safely and efficiently.
#
# ### Who We Serve
# More than **50,000 organizations** including industry giants such as Google, Microsoft, and Amazon trust Hugging Face to accelerate their AI initiatives. Our diverse customer base spans across non-profits to tech enterprises, showcasing the versatility and effectiveness of our offerings.
#
# ---
#
# ### Company Culture
#
# At Hugging Face, we pride ourselves on fostering a collaborative and inclusive culture. We believe in the power of community and strive to cultivate an environment where innovation flourishes. Our team is composed of passionate individuals dedicated to advancing machine learning and making AI accessible to everyone.
#
# #### Careers at Hugging Face
# We're always on the lookout for talented individuals to join our team and contribute to our mission. Our current openings offer a wide range of opportunities for both technical and non-technical roles. We value entrepreneurship, creativity, and a passion for artificial intelligence.
#
# ---
#
# ### Join Us Today!
# Explore our platform, participate in the community, and help us build the future of AI! Whether you're a researcher, developer, or someone interested in starting a career in AI, Hugging Face has something for you.
#
# - **Visit Our Website**: [Hugging Face](https://huggingface.co)
# - **Follow Us on Social Media**: GitHub, Twitter, LinkedIn, Discord
#
# ---
#
# Together, let’s unlock the future of artificial intelligence, one model, one dataset, and one application at a time!
